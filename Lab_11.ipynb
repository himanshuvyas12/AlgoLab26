# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshuvyas12/AlgoLab26/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1] * (1 << n) for _ in range(n)]
    parent = [[-1] * (1 << n) for _ in range(n)]
    def visit(city, mask):
        if mask == (1 << n) - 1:
            return graph[city][0]
        if dp[city][mask] != -1:
            return dp[city][mask]
        ans = float('inf')
        for next_city in range(n):
            if mask & (1 << next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1 << next_city))
                if new_cost < ans:
                    ans = new_cost
                    parent[city][mask] = next_city
        dp[city][mask] = ans
        return ans
    min_cost = visit(0, 1)
    path = [0]
    mask = 1
    city = 0
    while True:
        next_city = parent[city][mask]
        if next_city == -1:
            break
        path.append(next_city)
        mask |= (1 << next_city)
        city = next_city
    path.append(0)
    return min_cost, path

# %%
2n = int(input("Enter number of cities: "))
print("Enter the distance matrix row by row:")
graph = []
for i in range(n):
    row = list(map(int, input().split()))
    graph.append(row)
cost, path = tsp(graph)
print("Minimum travelling cost:", cost)
print("Path taken:", path)
# Out:
# Enter number of cities: 2
# Enter the distance matrix row by row:
# 2 2
# 2
# Minimum travelling cost: 4
# Path taken: [0, 1, 0]

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
def dfs(city, graph, visited, path):
    visited.add(city)
    path.append(city)

    for neighbor in graph[city]:
        if neighbor not in visited:
            dfs(neighbor, graph, visited, path)


# Take input
n = int(input("Enter number of cities: "))
m = int(input("Enter number of connections (edges): "))

# Initialize graph
graph = {}


print("Enter city names:")
for i in range(n):
    city = input()
    graph[city] = []

print("Enter connections (city1 city2):")
for i in range(m):
    c1, c2 = input().split()
    graph[c1].append(c2)
    graph[c2].append(c1)  # undirected graph

# Start traversal
start = input("Enter starting city: ")

visited = set()
path = []

dfs(start, graph, visited, path)

print("Path of cities visited:")
print(" -> ".join(path))
# Out:
# Enter number of cities: 4
# Enter number of connections (edges): 4
# Enter city names:
# A
# B
# C
# D
# Enter connections (city1 city2):
# A B
# B C
# C D
# D A
# Enter starting city: A
# Path of cities visited:
# A -> B -> C -> D

# %%
from collections import deque

def bfs(start, graph):
    visited = set()
    queue = deque([start])
    path = []

    visited.add(start)

    while queue:
        city = queue.popleft()
        path.append(city)

        for neighbor in graph[city]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

    return path


# Call BFS instead
path = bfs(start, graph)
print("Path of cities visited:")
print(" -> ".join(path))
# Out:
# Path of cities visited:
# A -> B -> D -> C
